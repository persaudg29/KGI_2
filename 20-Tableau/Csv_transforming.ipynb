# %%
import pandas as pd
import datetime
import numpy as np
import os

# %%
path_1 = os.path.join("201801-citibike-tripdata.csv")
bike_2018_01 = pd.read_csv(path_1)
bike_2018_01.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1           723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2           496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3           306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4           306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id         end station name  \
# 0               -73.993929             505          6 Ave & W 33 St
# ...

# %%
bike_2018_01.count()
# Out:
# tripduration               718994
# starttime                  718994
# stoptime                   718994
# start station id           718994
# start station name         718994
# start station latitude     718994
# start station longitude    718994
# end station id             718994
# end station name           718994
# end station latitude       718994
# end station longitude      718994
# bikeid                     718994
# usertype                   718994
# birth year                 718994
# gender                     718994
# dtype: int64

# %%
path_2 = os.path.join("201802-citibike-tripdata.csv")
bike_2018_02 = pd.read_csv(path_2)
bike_2018_02.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           771  2018-02-01 00:14:16.4120  2018-02-01 00:27:08.2290
# 1           264  2018-02-01 05:14:45.1790  2018-02-01 05:19:09.6860
# 2           819  2018-02-01 06:48:55.2290  2018-02-01 07:02:35.0290
# 3           646  2018-02-01 07:12:50.1740  2018-02-01 07:23:36.5280
# 4          1312  2018-02-01 07:46:48.8750  2018-02-01 08:08:41.5430
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id               end station name  \
# 0               -73.993929             379                W 31 St & 7 Ave
# ...

# %%
combined_frame = pd.concat([bike_2018_01, bike_2018_02])

# %%
combined_frame.count()
# Out:
# tripduration               1562108
# starttime                  1562108
# stoptime                   1562108
# start station id           1562108
# start station name         1562108
# start station latitude     1562108
# start station longitude    1562108
# end station id             1562108
# end station name           1562108
# end station latitude       1562108
# end station longitude      1562108
# bikeid                     1562108
# usertype                   1562108
# birth year                 1562108
# gender                     1562108
# dtype: int64

# %%
path_3 = os.path.join("combined_frame.csv")
combined_frame.to_csv(path_3, index = False)

# %%
combined_frame.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           970  2018-01-01 13:50:57.4340  2018-01-01 14:07:08.1860
# 1           723  2018-01-01 15:33:30.1820  2018-01-01 15:45:33.3410
# 2           496  2018-01-01 15:39:18.3370  2018-01-01 15:47:35.1720
# 3           306  2018-01-01 15:40:13.3720  2018-01-01 15:45:20.1910
# 4           306  2018-01-01 18:14:51.5680  2018-01-01 18:19:57.6420
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id         end station name  \
# 0               -73.993929             505          6 Ave & W 33 St
# ...

# %%
combined_frame.tail()
# Out:
#         tripduration                 starttime                  stoptime  \
# 843109           510  2018-02-28 20:54:35.4120  2018-02-28 21:03:06.2820
# 843110          1953  2018-02-28 20:57:26.0010  2018-02-28 21:29:59.7280
# 843111           562  2018-02-28 21:15:38.6340  2018-02-28 21:25:01.5660
# 843112          1013  2018-02-28 21:43:14.6540  2018-02-28 22:00:08.5460
# 843113          2357  2018-02-28 22:49:10.4780  2018-02-28 23:28:28.3710
#
#         start station id             start station name  \
# 843109              3664  North Moore St & Greenwich St
# 843110              3664  North Moore St & Greenwich St
# 843111              3664  North Moore St & Greenwich St
# 843112              3664  North Moore St & Greenwich St
# 843113              3664  North Moore St & Greenwich St
#
#         start station latitude  start station longitude  end station id  \
# 843109               40.720195               -74.010301             306
# ...
